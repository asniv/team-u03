# %% [markdown]
# # COVID Cases in the US

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from bokeh.plotting import figure, show

# %%
# uploading cases from the USA data
start_date = datetime.date(2021,1,1)
end_date = datetime.date(2021,4,14)

dates = pd.date_range(start_date,end_date-datetime.timedelta(days=1),freq='d')
dates_str = dates.strftime("%m-%d-%Y")

# %%
# Collect list of files for all the selected dates

file_list = [ ('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/'
            + date
            + '.csv') for date in dates_str ]

# %%
# %%time

# List of DataFrames - each one covers one day of global data
df_list = [ pd.read_csv(file) for file in file_list ]
# Out:
# Wall time: 46.2 s

# %%
# DataFrame that contains all the files' data 

super_cases = pd.concat(df_list)
super_cases
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 0      NaN    NaN            NaN         Afghanistan  2021-01-02 05:22:33
# 1      NaN    NaN            NaN             Albania  2021-01-02 05:22:33
# 2      NaN    NaN            NaN             Algeria  2021-01-02 05:22:33
# 3      NaN    NaN            NaN             Andorra  2021-01-02 05:22:33
# 4      NaN    NaN            NaN              Angola  2021-01-02 05:22:33
# ...    ...    ...            ...                 ...                  ...
# 3978   NaN    NaN            NaN             Vietnam  2021-04-14 04:20:41
# 3979   NaN    NaN            NaN  West Bank and Gaza  2021-04-14 04:20:41
# 3980   NaN    NaN            NaN               Yemen  2021-04-14 04:20:41
# 3981   NaN    NaN            NaN              Zambia  2021-04-14 04:20:41
# 3982   NaN    NaN            NaN            Zimbabwe  2021-04-14 04:20:41
#
#             Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 0     33.939110   67.709953      51526    2191    41727.0      0.0
# 1     41.153300   20.168300      58316    1181    33634.0  23501.0
# 2     28.033900    1.659600      99897    2762    67395.0  29740.0
# 3     42.506300    1.521800       8117      84     7463.0    570.0
# 4    -11.202700   17.873900      17568     405    11146.0   6017.0
# ...         ...         ...        ...     ...        ...      ...
# 3978  14.058324  108.277199       2714      35     2445.0    234.0
# 3979  31.952200   35.233200     272767    2901   237046.0  32820.0
# 3980  15.552727   48.516388       5507    1073     2070.0   2364.0
# 3981 -13.133897   27.849332      90218    1229    88144.0    845.0
# 3982 -19.015438   29.154857      37330    1543    34932.0    855.0
#
#             Combined_Key  Incident_Rate Case_Fatality_Ratio
# 0            Afghanistan       0.000000            4.252222
# 1                Albania    2026.409062            2.025173
# 2                Algeria     227.809861            2.764848
# 3                Andorra   10505.403482            1.034865
# 4                 Angola      53.452981            2.305328
# ...                  ...            ...                 ...
# 3978             Vietnam       2.788206            1.289609
# 3979  West Bank and Gaza    5346.888001            1.063545
# 3980               Yemen      18.463776           19.484293
# 3981              Zambia     490.743124            1.362256
# 3982            Zimbabwe     251.161834            4.133405
#
# [410213 rows x 14 columns]

# %%
# Data from only US counties (counties stored in Admin2)

US_cases = super_cases[super_cases['Country_Region'] == 'US']
US_cases
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 649    1001.0     Autauga        Alabama             US  2021-01-02 05:22:33
# 650    1003.0     Baldwin        Alabama             US  2021-01-02 05:22:33
# 651    1005.0     Barbour        Alabama             US  2021-01-02 05:22:33
# 652    1007.0        Bibb        Alabama             US  2021-01-02 05:22:33
# 653    1009.0      Blount        Alabama             US  2021-01-02 05:22:33
# ...       ...         ...            ...            ...                  ...
# 3924  56039.0       Teton        Wyoming             US  2021-04-14 04:20:41
# 3925  56041.0       Uinta        Wyoming             US  2021-04-14 04:20:41
# 3926  90056.0  Unassigned        Wyoming             US  2021-04-14 04:20:41
# 3927  56043.0    Washakie        Wyoming             US  2021-04-14 04:20:41
# 3928  56045.0      Weston        Wyoming             US  2021-04-14 04:20:41
#
#             Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 649   32.539527  -86.644082       4239      50        0.0   4189.0
# 650   30.727750  -87.722071      13823     169        0.0  13654.0
# 651   31.868263  -85.387129       1517      33        0.0   1484.0
# 652   32.996421  -87.125115       1854      46        0.0   1808.0
# 653   33.982109  -86.567906       4693      63        0.0   4630.0
# ...         ...         ...        ...     ...        ...      ...
# 3924  43.935225 -110.589080       3675       9        NaN      NaN
# 3925  41.287818 -110.547578       2153      12        NaN      NaN
# 3926        NaN         NaN          0       0        NaN      NaN
# 3927  43.904516 -107.680187        898      26        NaN      NaN
# 3928  43.839612 -104.567488        642       5        NaN      NaN
#
#                  Combined_Key  Incident_Rate Case_Fatality_Ratio
# 649      Autauga, Alabama, US    7587.391935            1.179523
# 650      Baldwin, Alabama, US    6192.157109              1.2226
# 651      Barbour, Alabama, US    6145.183505            2.175346
# 652         Bibb, Alabama, US    8279.003304            2.481122
# 653       Blount, Alabama, US    8115.726490            1.342425
# ...                       ...            ...                 ...
# 3924       Teton, Wyoming, US   15662.291169            0.244898
# 3925       Uinta, Wyoming, US   10644.714724            0.557362
# 3926  Unassigned, Wyoming, US            NaN                 NaN
# 3927    Washakie, Wyoming, US   11505.445227            2.895323
# 3928      Weston, Wyoming, US    9268.081421            0.778816
#
# [337517 rows x 14 columns]

# %%
# Latest Date for first cell's Last Update
US_cases.iloc[0].loc['Last_Update']
# Out:
# '2021-01-02 05:22:33'

# %%
# %%time
states2 = US_cases['Province_State'].to_list()
states2 = list(set(states2))
states2.sort()
# Out:
# Wall time: 11.9 ms

# %%
states2
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Diamond Princess',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Grand Princess',
#  'Guam',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Northern Mariana Islands',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Recovered',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virgin Islands',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
# %%time
US_cases.loc[:, 'DateTime'] = pd.to_datetime(US_cases.loc[:, 'Last_Update'], format='%Y-%m-%d')
US_cases[['year','month','day']] = US_cases.DateTime.apply(lambda x: pd.Series(x.strftime("%Y,%m,%d").split(",")))#.astype(int)
# Out:
# Wall time: 1min 37s

# %%
# US_cases['MonthYear'] = US_cases['month'].concat(US_cases['year'], sep=',')
# US_cases
# cols=[]
#US_cases["MonthYear"] = US_cases["month"].str.cat(US_cases[["year"]].astype(float), sep=".")
#df['MonthYear'] = df[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)
# US_cases['MonthYear'] = US_cases.month.str.cat([US_cases.year.str])
# US_cases['MonthYear']= US_cases['MonthYear'].astype(int)
US_cases['YearMonthDay'] = US_cases.year.astype(str) + US_cases.month.astype(str) + US_cases.day.astype(str)
US_cases
# Out:
# C:\Users\amand\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 649    1001.0     Autauga        Alabama             US  2021-01-02 05:22:33
# 650    1003.0     Baldwin        Alabama             US  2021-01-02 05:22:33
# 651    1005.0     Barbour        Alabama             US  2021-01-02 05:22:33
# 652    1007.0        Bibb        Alabama             US  2021-01-02 05:22:33
# 653    1009.0      Blount        Alabama             US  2021-01-02 05:22:33
# ...       ...         ...            ...            ...                  ...
# 3924  56039.0       Teton        Wyoming             US  2021-04-14 04:20:41
# 3925  56041.0       Uinta        Wyoming             US  2021-04-14 04:20:41
# 3926  90056.0  Unassigned        Wyoming             US  2021-04-14 04:20:41
# 3927  56043.0    Washakie        Wyoming             US  2021-04-14 04:20:41
# 3928  56045.0      Weston        Wyoming             US  2021-04-14 04:20:41
#
#             Lat       Long_  Confirmed  Deaths  Recovered  ...  \
# 649   32.539527  -86.644082       4239      50        0.0  ...
# 650   30.727750  -87.722071      13823     169        0.0  ...
# 651   31.868263  -85.387129       1517      33        0.0  ...
# 652   32.996421  -87.125115       1854      46        0.0  ...
# 653   33.982109  -86.567906       4693      63        0.0  ...
# ...         ...         ...        ...     ...        ...  ...
# 3924  43.935225 -110.589080       3675       9        NaN  ...
# 3925  41.287818 -110.547578       2153      12        NaN  ...
# 3926        NaN         NaN          0       0        NaN  ...
# 3927  43.904516 -107.680187        898      26        NaN  ...
# 3928  43.839612 -104.567488        642       5        NaN  ...
#
#                  Combined_Key Incident_Rate  Case_Fatality_Ratio  \
# 649      Autauga, Alabama, US   7587.391935             1.179523
# 650      Baldwin, Alabama, US   6192.157109               1.2226
# 651      Barbour, Alabama, US   6145.183505             2.175346
# 652         Bibb, Alabama, US   8279.003304             2.481122
# 653       Blount, Alabama, US   8115.726490             1.342425
# ...                       ...           ...                  ...
# 3924       Teton, Wyoming, US  15662.291169             0.244898
# 3925       Uinta, Wyoming, US  10644.714724             0.557362
# 3926  Unassigned, Wyoming, US           NaN                  NaN
# 3927    Washakie, Wyoming, US  11505.445227             2.895323
# 3928      Weston, Wyoming, US   9268.081421             0.778816
#
#                 DateTime  year month day MonthYear  MonthDayYear YearMonthDay
# 649  2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 650  2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 651  2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 652  2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 653  2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# ...                  ...   ...   ...  ..       ...           ...          ...
# 3924 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3925 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3926 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3927 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3928 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
#
# [337517 rows x 21 columns]

# %%
US_cases_grouped = US_cases.groupby('YearMonthDay').agg({'Confirmed': np.sum, 'Deaths': np.sum,'YearMonthDay':'first'})

# %%
X = US_cases_grouped['YearMonthDay']
y = US_cases_grouped.loc[:,'Confirmed']

p = figure(title='USA Cases', x_axis_label='Time', y_axis_label='Cases')
p.line(X,y,legend_label='USA')
show(p)

# %%
US_cases_grouped
# Out:
#               Confirmed  Deaths YearMonthDay
# YearMonthDay
# 20200804          15656     309     20200804
# 20200807              0       0     20200807
# 20201221          74580     256     20201221
# 20201229           9144      72     20201229
# 20210102       20249514  354247     20210102
# ...                 ...     ...          ...
# 20210410       31084810  561465     20210410
# 20210411       31151345  562178     20210411
# 20210412       31197725  562474     20210412
# 20210413       31267955  562947     20210413
# 20210414       31345833  563776     20210414
#
# [107 rows x 3 columns]

# %%
# hoverable plot
import plotly.express as px

fig = px.line(US_cases_grouped, x="YearMonthDay", y="Confirmed", title="layout.hovermode='closest' (the default)")
fig.update_traces(mode="markers+lines")
#, color="country"
fig.show()
# Out:
# <div>                            <div id="01c2f9ed-1f3a-4d32-8f8f-f7c8e7f7c189" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01c2f9ed-1f3a-4d32-8f8f-f7c8e7f7c189")) {                    Plotly.newPlot(                        "01c2f9ed-1f3a-4d32-8f8f-f7c8e7f7c189",                        [{"hovertemplate": "YearMonthDay=%{x}<br>Confirmed=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["20200804", "20200807", "20201221", "20201229", "20210102", "20210103", "20210104", "20210105", "20210106", "20210107", "20210108", "20210109", "20210110", "20210111", "20210112", "20210113", "20210114", "20210115", "20210116", "20210117", "20210118", "20210119", "20210120", "20210121", "20210122", "20210123", "20210124", "20210125", "20210126", "20210127", "20210128", "20210129", "20210130", "20210131", "20210201", "20210202", "20210203", "20210204", "20210205", "20210206", "20210207", "20210208", "20210209", "20210210", "20210211", "20210212", "20210213", "20210214", "20210215", "20210216", "20210217", "20210218", "20210219", "20210220", "20210221", "20210222", "20210223", "20210224", "20210225", "20210226", "20210227", "20210228", "20210301", "20210302", "20210303", "20210304", "20210305", "20210306", "20210307", "20210308", "20210309", "20210310", "20210311", "20210312", "20210313", "20210314", "20210315", "20210316", "20210317", "20210318", "20210319", "20210320", "20210321", "20210322", "20210323", "20210324", "20210325", "20210326", "20210327", "20210328", "20210329", "20210330", "20210331", "20210401", "20210402", "20210403", "20210404", "20210405", "20210406", "20210407", "20210408", "20210409", "20210410", "20210411", "20210412", "20210413", "20210414"], "xaxis": "x", "y": [15656, 0, 74580, 9144, 20249514, 20549931, 20758686, 20943001, 21180347, 21435752, 21713838, 22009030, 22269758, 22483035, 22698035, 22925000, 23155360, 23390977, 23633721, 23835372, 24013179, 24156587, 24333343, 24516564, 24710329, 24901021, 25071657, 25202695, 25354685, 25502275, 25656179, 25824783, 25991291, 26133623, 26245646, 26380836, 26496185, 26617812, 26741748, 26876116, 26980113, 27069782, 27160146, 27255777, 27350928, 27456644, 27556275, 27643410, 27708441, 27762637, 27825369, 27895474, 27965357, 28044652, 28116172, 28173234, 28229469, 28301732, 28376447, 28453951, 28531255, 28595795, 28647194, 28705447, 28762496, 28829699, 28897703, 28964112, 29022319, 29063353, 29108389, 29166028, 29223981, 29286397, 29347835, 29400827, 29439058, 29495724, 29549675, 29608791, 29669305, 29730841, 29786295, 29820069, 29871652, 29925291, 30012247, 30079703, 30157049, 30219733, 30262829, 30332255, 30394457, 30461496, 30583322, 30610934, 30674001, 30708973, 30786652, 30847196, 30922234, 31002112, 31084810, 31151345, 31197725, 31267955, 31345833], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222 ...

# %% [markdown]
# ## COVID cases by states

# %%
state1 = input('What state?')
# Out:
# What state?Texas

# %%
state2=input('What state?')
# Out:
# What state?Ohio

# %%
index1 = (US_cases['Province_State']==state1).index
index2 = (US_cases['Province_State']==state2).index

# %%
state_cases1 = US_cases[(US_cases['Province_State']==state1)]
state_cases1
# Out:
#          FIPS    Admin2 Province_State Country_Region          Last_Update  \
# 3311  48001.0  Anderson          Texas             US  2021-01-02 05:22:33
# 3312  48003.0   Andrews          Texas             US  2021-01-02 05:22:33
# 3313  48005.0  Angelina          Texas             US  2021-01-02 05:22:33
# 3314  48007.0   Aransas          Texas             US  2021-01-02 05:22:33
# 3315  48009.0    Archer          Texas             US  2021-01-02 05:22:33
# ...       ...       ...            ...            ...                  ...
# 3567  48499.0      Wood          Texas             US  2021-04-14 04:20:41
# 3568  48501.0    Yoakum          Texas             US  2021-04-14 04:20:41
# 3569  48503.0     Young          Texas             US  2021-04-14 04:20:41
# 3570  48505.0    Zapata          Texas             US  2021-04-14 04:20:41
# 3571  48507.0    Zavala          Texas             US  2021-04-14 04:20:41
#
#             Lat       Long_  Confirmed  Deaths  Recovered  ...  \
# 3311  31.815347  -95.653548       4814      65        0.0  ...
# 3312  32.304686 -102.637655       1433      25        0.0  ...
# 3313  31.254573  -94.609015       5696     149        0.0  ...
# 3314  28.105562  -96.999505        737      23        0.0  ...
# 3315  33.615700  -98.687546        562       6        0.0  ...
# ...         ...         ...        ...     ...        ...  ...
# 3567  32.787224  -95.382364       3368     125        NaN  ...
# 3568  33.173202 -102.827643        868      27        NaN  ...
# 3569  33.176597  -98.687909       2141      44        NaN  ...
# 3570  27.001564  -99.169872       1762      34        NaN  ...
# 3571  28.866172  -99.760508       1849      40        NaN  ...
#
#              Combined_Key Incident_Rate  Case_Fatality_Ratio  \
# 3311  Anderson, Texas, US   8338.096475             1.350229
# 3312   Andrews, Texas, US   7661.053194             1.744592
# 3313  Angelina, Texas, US   6568.644410             2.615871
# 3314   Aransas, Texas, US   3134.836240              3.12076
# 3315    Archer, Texas, US   6570.793873             1.067616
# ...                   ...           ...                  ...
# 3567      Wood, Texas, US   7395.858495             3.711401
# 3568    Yoakum, Texas, US   9962.125560             3.110599
# 3569     Young, Texas, US  11887.840089             2.055114
# 3570    Zapata, Texas, US  12426.828408             1.929625
# 3571    Zavala, Texas, US  15616.554054             2.163332
#
#                 DateTime  year month day MonthYear  MonthDayYear YearMonthDay
# 3311 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 3312 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 3313 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 3314 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 3315 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# ...                  ...   ...   ...  ..       ...           ...          ...
# 3567 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3568 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3569 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3570 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 3571 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
#
# [26265 rows x 21 columns]

# %%
state_cases2= US_cases[(US_cases['Province_State']==state2)]
state_cases2
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 2740  39001.0       Adams           Ohio             US  2021-01-02 05:22:33
# 2741  39003.0       Allen           Ohio             US  2021-01-02 05:22:33
# 2742  39005.0     Ashland           Ohio             US  2021-01-02 05:22:33
# 2743  39007.0   Ashtabula           Ohio             US  2021-01-02 05:22:33
# 2744  39009.0      Athens           Ohio             US  2021-01-02 05:22:33
# ...       ...         ...            ...            ...                  ...
# 2830  39167.0  Washington           Ohio             US  2021-04-14 04:20:41
# 2831  39169.0       Wayne           Ohio             US  2021-04-14 04:20:41
# 2832  39171.0    Williams           Ohio             US  2021-04-14 04:20:41
# 2833  39173.0        Wood           Ohio             US  2021-04-14 04:20:41
# 2834  39175.0     Wyandot           Ohio             US  2021-04-14 04:20:41
#
#             Lat      Long_  Confirmed  Deaths  Recovered  ...  \
# 2740  38.845411 -83.471896       1367      28        0.0  ...
# 2741  40.772852 -84.108023       8308     179        0.0  ...
# 2742  40.847723 -82.272808       2729      71        0.0  ...
# 2743  41.708603 -80.748302       3829     127        0.0  ...
# 2744  39.334256 -82.042786       3101      25        0.0  ...
# ...         ...        ...        ...     ...        ...  ...
# 2830  39.456906 -81.491214       5053     108        NaN  ...
# 2831  40.829259 -81.888448       8506     210        NaN  ...
# 2832  41.560520 -84.584296       3205      74        NaN  ...
# 2833  41.362248 -83.622851      12626     187        NaN  ...
# 2834  40.843396 -83.307342       2252      54        NaN  ...
#
#               Combined_Key Incident_Rate  Case_Fatality_Ratio  \
# 2740       Adams, Ohio, US   4935.374395              1.02414
# 2741       Allen, Ohio, US   8117.165440             1.336062
# 2742     Ashland, Ohio, US   5102.460549             1.355808
# 2743   Ashtabula, Ohio, US   3937.639473             1.723688
# 2744      Athens, Ohio, US   4746.888729             0.290229
# ...                    ...           ...                  ...
# 2830  Washington, Ohio, US   8434.177363             2.117554
# 2831       Wayne, Ohio, US   7351.136462             2.457089
# 2832    Williams, Ohio, US   8734.874087             2.308892
# 2833        Wood, Ohio, US   9651.650779              1.45731
# 2834     Wyandot, Ohio, US  10343.560536             2.353464
#
#                 DateTime  year month day MonthYear  MonthDayYear YearMonthDay
# 2740 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 2741 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 2742 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 2743 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# 2744 2021-01-02 05:22:33  2021    01  02     12021      01022021     20210102
# ...                  ...   ...   ...  ..       ...           ...          ...
# 2830 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 2831 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 2832 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 2833 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
# 2834 2021-04-14 04:20:41  2021    04  14     42021      04142021     20210414
#
# [9167 rows x 21 columns]

# %%
#state_cases
state_cases1_grouped = state_cases1.groupby('YearMonthDay').agg({'Confirmed': np.sum, 'Deaths': np.sum,'YearMonthDay':'first'})
#state_cases
state_cases2_grouped = state_cases2.groupby('YearMonthDay').agg({'Confirmed': np.sum, 'Deaths': np.sum,'YearMonthDay':'first'})

# %%
state_cases_grouped
# Out:
#               Confirmed  Deaths YearMonthDay
# YearMonthDay
# 20210102        1782956   28359     20210102
# 20210103        1801181   28442     20210103
# 20210104        1816886   28496     20210104
# 20210105        1831146   28570     20210105
# 20210106        1864173   28808     20210106
# ...                 ...     ...          ...
# 20210410        2822889   49121     20210410
# 20210411        2825551   49188     20210411
# 20210412        2826977   49212     20210412
# 20210413        2831972   49231     20210413
# 20210414        2837160   49289     20210414
#
# [103 rows x 3 columns]

# %%
# hoverable plot
import plotly.express as px

fig = px.line(state_cases1_grouped, x="YearMonthDay", y="Confirmed", title="layout.hovermode='closest' (the default)")
fig = px.line(state_cases2_grouped, x="YearMonthDay", y="Confirmed", title="layout.hovermode='closest' (the default)")

fig.update_traces(mode="markers+lines")
#, color="country"
fig.show()
# Out:
# <div>                            <div id="f9a8d38f-4a4c-4a57-9331-0e0c378a3181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9a8d38f-4a4c-4a57-9331-0e0c378a3181")) {                    Plotly.newPlot(                        "f9a8d38f-4a4c-4a57-9331-0e0c378a3181",                        [{"hovertemplate": "YearMonthDay=%{x}<br>Confirmed=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["20210102", "20210103", "20210104", "20210105", "20210106", "20210107", "20210108", "20210109", "20210110", "20210111", "20210112", "20210113", "20210114", "20210115", "20210116", "20210117", "20210118", "20210119", "20210120", "20210121", "20210122", "20210123", "20210124", "20210125", "20210126", "20210127", "20210128", "20210129", "20210130", "20210131", "20210201", "20210202", "20210203", "20210204", "20210205", "20210206", "20210207", "20210208", "20210209", "20210210", "20210211", "20210212", "20210213", "20210214", "20210215", "20210216", "20210217", "20210218", "20210219", "20210220", "20210221", "20210222", "20210223", "20210224", "20210225", "20210226", "20210227", "20210228", "20210301", "20210302", "20210303", "20210304", "20210305", "20210306", "20210307", "20210308", "20210309", "20210310", "20210311", "20210312", "20210313", "20210314", "20210315", "20210316", "20210317", "20210318", "20210319", "20210320", "20210321", "20210322", "20210323", "20210324", "20210325", "20210326", "20210327", "20210328", "20210329", "20210330", "20210331", "20210401", "20210402", "20210403", "20210404", "20210405", "20210406", "20210407", "20210408", "20210409", "20210410", "20210411", "20210412", "20210413", "20210414"], "xaxis": "x", "y": [700380, 714673, 721481, 727423, 735003, 742817, 753068, 762603, 770977, 777065, 784957, 792938, 799639, 807293, 814442, 821507, 826754, 831066, 836049, 842433, 849704, 853982, 859841, 864322, 868656, 872918, 878284, 883716, 888590, 892781, 895792, 899079, 902736, 906727, 910847, 914530, 918079, 920217, 922143, 925350, 928631, 931437, 934742, 937541, 939350, 941265, 943291, 945107, 947389, 949695, 952306, 953767, 955378, 958153, 959995, 962404, 964380, 966154, 967422, 968874, 970583, 972605, 974480, 976230, 977736, 978471, 979725, 981618, 983486, 984934, 986740, 988298, 989191, 990340, 992223, 993681, 995785, 997336, 998819, 999750, 1001194, 1002822, 1004670, 1006171, 1008913, 1010603, 1011622, 1013119, 1015577, 1017566, 1020041, 1021718, 1024011, 1024011, 1026929, 1028800, 1030864, 1033606, 1035552, 1037600, 1039455, 1041389, 1043729], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], ...

# %%
import plotly.graph_objects as go
import numpy as np
#t = np.linspace(0, 2 * np.pi, 100)
fig = go.Figure()
fig.add_trace(go.Scatter(x="YearMonthDay", y='Confirmed')
#fig.add_trace(go.Scatter(x=t, y=np.cos(t), name='cost(t)'))
fig.update_layout(hovermode='x unified')
fig.show()
# Out:
#   File "<ipython-input-147-f69a05e92f52>", line 7
#     fig.update_layout(hovermode='x unified')
#       ^
# SyntaxError: invalid syntax
